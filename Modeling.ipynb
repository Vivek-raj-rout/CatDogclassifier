# %%
import numpy as np
import pandas as pd
import cv2
import pickle 
from keras.models import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten

# %%
x=pickle.load(open('x.pkl','rb') )
y=pickle.load(open('y.pkl','rb') )

# %%
x=x/255

# %%
x
# Out:
# array([[[[0.39215686, 0.40392157, 0.39607843],
#          [0.42745098, 0.43921569, 0.43137255],
#          [0.50980392, 0.51764706, 0.50980392],
#          ...,
#          [0.2       , 0.21176471, 0.20392157],
#          [0.20392157, 0.21568627, 0.21176471],
#          [0.20392157, 0.21568627, 0.23137255]],
#
#         [[0.38039216, 0.39215686, 0.38431373],
#          [0.45490196, 0.46666667, 0.45882353],
#          [0.45098039, 0.4627451 , 0.45490196],
#          ...,
#          [0.20392157, 0.21568627, 0.20784314],
#          [0.21176471, 0.22352941, 0.21960784],
#          [0.18823529, 0.20392157, 0.21176471]],
#
#         [[0.42745098, 0.43921569, 0.43137255],
#          [0.47058824, 0.48235294, 0.4745098 ],
#          [0.48235294, 0.49411765, 0.48627451],
#          ...,
#          [0.20784314, 0.21960784, 0.21176471],
#          [0.22352941, 0.23529412, 0.22352941],
#          [0.19607843, 0.21568627, 0.21176471]],
#
#         ...,
#
#         [[0.24705882, 0.28235294, 0.29803922],
#          [0.27058824, 0.30588235, 0.32156863],
#          [0.25882353, 0.29411765, 0.31372549],
#          ...,
#          [0.11764706, 0.2627451 , 0.49411765],
#          [0.09411765, 0.23137255, 0.45098039],
#          [0.08235294, 0.21568627, 0.42745098]],
#
#         [[0.25882353, 0.29411765, 0.30980392],
#          [0.2627451 , 0.29803922, 0.31372549],
#          [0.29019608, 0.3254902 , 0.34117647],
#          ...,
#          [0.11372549, 0.25882353, 0.49019608],
#          [0.08235294, 0.21960784, 0.43921569],
#          [0.08627451, 0.21960784, 0.42745098]],
#
#         [[0.24313725, 0.28235294, 0.27843137],
#          [0.27058824, 0.30588235, 0.31764706],
#          [0.29019608, 0.3254902 , 0.34117647],
#          ...,
#          [0.08235294, 0.23137255, 0.46666667],
#          [0.10980392, 0.22352941, 0.43921569],
#          [0.09019608, 0.20392157, 0.43137255]]],
#
#
#        [[[0.19215686, 0.30196078, 0.2       ],
#          [0.25098039, 0.36078431, 0.25882353],
#          [0.30196078, 0.42352941, 0.31764706],
#          ...,
#          [0.21960784, 0.39215686, 0.26666667],
#          [0.23137255, 0.40784314, 0.27843137],
#          [0.28235294, 0.45882353, 0.31372549]],
#
#         [[0.17647059, 0.28235294, 0.18823529],
#          [0.17254902, 0.28627451, 0.18431373],
#          [0.18039216, 0.29411765, 0.19607843],
#          ...,
#          [0.22745098, 0.4       , 0.27843137],
#          [0.25098039, 0.42745098, 0.29803922],
#          [0.32156863, 0.49411765, 0.35294118]],
#
#         [[0.19607843, 0.30588235, 0.21568627],
#          [0.14901961, 0.2627451 , 0.17254902],
#          [0.11764706, 0.23137255, 0.14509804],
#          ...,
#          [0.16862745, 0.34117647, 0.21960784],
#          [0.23529412, 0.41176471, 0.28235294],
#          [0.3372549 , 0.50980392, 0.36862745]],
#
#         ...,
#
#         [[0.45882353, 0.55686275, 0.65882353],
#          [0.53333333, 0.63137255, 0.73333333],
#          [0.61176471, 0.71372549, 0.80784314],
#          ...,
#          [0.12941176, 0.2627451 , 0.32941176],
#          [0.12156863, 0.2627451 , 0.32941176],
#          [0.14117647, 0.28235294, 0.35686275]],
#
#         [[0.33333333, 0.43137255, 0.53333333],
#          [0.4       , 0.49803922, 0.6       ],
#          [0.48627451, 0.58431373, 0.68627451],
#          ...,
#          [0.16078431, 0.29411765, 0.35294118],
#          [0.1372549 , 0.2745098 , 0.33333333],
#          [0.13333333, 0.26666667, 0.33333333]],
#
#         [[0.58431373, 0.68235294, 0.78039216],
#          [0.54901961, 0.64705882, 0.74901961],
#          [0.50980392, 0.60784314, 0.70980392],
#          ...,
#          [0.24705882, 0.38431373, 0.43529412],
#          [0.18823529, 0.32941176, 0.38039216],
#          [0.16078431, 0.29411765, 0.35294118]]],
#
#
#        [[[0.00392157, 0.01568627, 0.03529412],
#          [0.00784314, 0.01568627, 0.04313725],
#          [0.03529412, 0.03921569, 0.07843137],
#          ...,
#          [0.10588235, 0.10588235, 0.12941176],
#          [0.0745098 , 0.0745098 , 0.09411765],
#          [0.03529412, 0.03921569, 0.05882353]],
#
#         [[0.00784314, 0.01568627, 0.04705882],
#          [0.03137255, 0.03529412, 0.07843137],
#          [0.05098039, 0.05882353, 0.11372549],
#          ...,
#          [0.2       , 0.21568627, 0.2       ],
#          [0.12941176, 0.14117647, 0.13333333],
#          [0.0627451 , 0.07058824, 0.0745098 ]],
#
#         [[0.02352941, 0.03137255, 0.0745098 ],
#          [0.06666667, 0.07058824, 0.12941176],
#          [0.09803922, 0.11372549, 0.18823529],
#          ...,
#          [0.29803922, 0.31764706, 0.28235294],
#          [0.18039216, 0.19215686, 0.18039216],
#          [0.09803922, 0.10588235, 0.10588235]],
#
#         ...,
#
#         [[0.        , 0.        , 0.03137255],
#          [0.        , 0.        , 0.03137255],
#          [0.        , 0.        , 0.03137255],
#          ...,
#          [0.31372549, 0.31372549, 0.3372549 ],
#          [0.19215686, 0.18823529, 0.21960784],
#          [0.10196078, 0.09803922, 0.12941176]],
#
#         [[0.        , 0.        , 0.03137255],
#          [0.        , 0.        , 0.03137255],
#          [0.        , 0.        , 0.03137255],
#          ...,
#          [0.19607843, 0.19215686, 0.22745098],
#          [0.11764706, 0.10980392, 0.14509804],
#          [0.05098039, 0.04705882, 0.08235294]],
#
#         [[0.        , 0.        , 0.03137255],
#          [0.        , 0.        , 0.03137255],
#          [0.        , 0.        , 0.03137255],
#          ...,
#          [0.09019608, 0.08627451, 0.12156863],
#          [0.05882353, 0.05490196, 0.08627451],
#          [0.02745098, 0.02352941, 0.05882353]]],
#
#
#        ...,
#
#
#        [[[0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          ...,
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647]],
#
#         [[0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          ...,
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647]],
#
#         [[0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          ...,
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647]],
#
#         ...,
#
#         [[0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          ...,
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647]],
#
#         [[0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          ...,
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647]],
#
#         [[0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          ...,
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647],
#          [0.        , 0.00392157, 0.74117647]]],
#
#
#        [[[0.40784314, 0.39607843, 0.36470588],
#          [0.40784314, 0.39607843, 0.36470588],
#          [0.4       , 0.38823529, 0.35686275],
#          ...,
#          [0.43529412, 0.41176471, 0.38431373],
#          [0.43137255, 0.40784314, 0.38039216],
#          [0.43137255, 0.40784314, 0.38039216]],
#
#         [[0.40784314, 0.39607843, 0.36470588],
#          [0.40784314, 0.39607843, 0.36470588],
#          [0.40392157, 0.39215686, 0.36078431],
#          ...,
#          [0.43529412, 0.41176471, 0.38431373],
#          [0.43137255, 0.40784314, 0.38039216],
#          [0.43137255, 0.40784314, 0.38039216]],
#
#         [[0.40784314, 0.39607843, 0.36470588],
#          [0.40784314, 0.39607843, 0.36470588],
#          [0.40784314, 0.39607843, 0.36470588],
#          ...,
#          [0.43529412, 0.41176471, 0.38431373],
#          [0.43137255, 0.40784314, 0.38039216],
#          [0.43137255, 0.40784314, 0.38039216]],
#
#         ...,
#
#         [[0.70980392, 0.71764706, 0.71764706],
#          [0.74901961, 0.75686275, 0.75686275],
#          [0.70588235, 0.71764706, 0.71764706],
#          ...,
#          [0.41960784, 0.4       , 0.36470588],
#          [0.41568627, 0.39607843, 0.36078431],
#          [0.41568627, 0.39607843, 0.36078431]],
#
#         [[0.70588235, 0.71372549, 0.71372549],
#          [0.71764706, 0.7254902 , 0.7254902 ],
#          [0.6627451 , 0.66666667, 0.66666667],
#          ...,
#          [0.41568627, 0.39607843, 0.36078431],
#          [0.41568627, 0.39607843, 0.36078431],
#          [0.41568627, 0.39607843, 0.36078431]],
#
#         [[0.93333333, 0.93333333, 0.93333333],
#          [0.92156863, 0.92156863, 0.92156863],
#          [0.89411765, 0.89411765, 0.89411765],
#          ...,
#          [0.40392157, 0.39215686, 0.36078431],
#          [0.40784314, 0.38431373, 0.35686275],
#          [0.40784314, 0.38431373, 0.35686275]]],
#
#
#        [[[0.06666667, 0.11764706, 0.01568627],
#          [0.0627451 , 0.0745098 , 0.0627451 ],
#          [0.05490196, 0.06666667, 0.04313725],
#          ...,
#          [0.18039216, 0.28235294, 0.34509804],
#          [0.14117647, 0.24313725, 0.30588235],
#          [0.15294118, 0.25490196, 0.31372549]],
#
#         [[0.11372549, 0.15294118, 0.05490196],
#          [0.07843137, 0.09411765, 0.07843137],
#          [0.0745098 , 0.08627451, 0.06666667],
#          ...,
#          [0.15686275, 0.25882353, 0.32156863],
#          [0.15686275, 0.25882353, 0.31764706],
#          [0.16078431, 0.2627451 , 0.3254902 ]],
#
#         [[0.16862745, 0.19607843, 0.09803922],
#          [0.0745098 , 0.06666667, 0.05490196],
#          [0.0745098 , 0.07843137, 0.05882353],
#          ...,
#          [0.16862745, 0.27058824, 0.33333333],
#          [0.17647059, 0.28235294, 0.34509804],
#          [0.16078431, 0.2627451 , 0.3254902 ]],
#
#         ...,
#
#         [[0.06666667, 0.05490196, 0.07843137],
#          [0.06666667, 0.05098039, 0.07058824],
#          [0.30980392, 0.33333333, 0.36470588],
#          ...,
#          [0.12941176, 0.14509804, 0.16470588],
#          [0.12156863, 0.14509804, 0.15294118],
#          [0.11372549, 0.12941176, 0.1372549 ]],
#
#         [[0.01960784, 0.09411765, 0.1254902 ],
#          [0.01960784, 0.03921569, 0.05490196],
#          [0.01960784, 0.02352941, 0.03529412],
#          ...,
#          [0.13333333, 0.14901961, 0.15294118],
#          [0.12941176, 0.14901961, 0.14901961],
#          [0.10980392, 0.14117647, 0.14117647]],
#
#         [[0.12941176, 0.30196078, 0.34901961],
#          [0.04705882, 0.11372549, 0.1254902 ],
#          [0.06666667, 0.05490196, 0.05882353],
#          ...,
#          [0.09803922, 0.10196078, 0.09019608],
#          [0.09803922, 0.11764706, 0.10588235],
#          [0.11372549, 0.14117647, 0.1254902 ]]]])

# %%
y
# Out:
# array([0, 1, 1, ..., 1, 0, 0])

# %%
model=Sequential()
#1st layer
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D((2,2)))
#2nd Layer
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D((2,2)))
#3rd Layer
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

#Dense Layer
model.add(Dense(128,input_shape=x.shape[1:],activation='relu'))
model.add(Dense(128,activation='relu'))
#Output Layer
model.add(Dense(2,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow
import time
from tensorflow.keras.callbacks import TensorBoard

# %%
file_name=f'classification_cat_dog-{int(time.time())}'
tensorboard = TensorBoard(log_dir='logs/')

# %%
model.fit(x,y,epochs=5,validation_split=0.1,batch_size=32,callbacks=[tensorboard])
# Out:
# Epoch 1/5
#   1/647 [..............................] - ETA: 0s - loss: 0.6976 - accuracy: 0.4688WARNING:tensorflow:From C:\Users\KIIT\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 647/647 [==============================] - 318s 491ms/step - loss: 0.6211 - accuracy: 0.6425 - val_loss: 0.5310 - val_accuracy: 0.7239
# Epoch 2/5
# 647/647 [==============================] - 329s 508ms/step - loss: 0.4901 - accuracy: 0.7605 - val_loss: 0.4864 - val_accuracy: 0.7626
# Epoch 3/5
# 647/647 [==============================] - 325s 502ms/step - loss: 0.4110 - accuracy: 0.8088 - val_loss: 0.3997 - val_accuracy: 0.8139
# Epoch 4/5
# 647/647 [==============================] - 323s 500ms/step - loss: 0.3566 - accuracy: 0.8395 - val_loss: 0.4099 - val_accuracy: 0.8204
# Epoch 5/5
# 647/647 [==============================] - 322s 498ms/step - loss: 0.2944 - accuracy: 0.8725 - val_loss: 0.4105 - val_accuracy: 0.8217
